# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/My Drive/classification.zip'

# %%
import os
import csv


csv_file = open('output2.csv', 'w', newline='')
csv_writer = csv.writer(csv_file)

add_empty_row = True

for filename in os.listdir(folder_path):
    if filename.endswith('.txt'):
        with open(os.path.join(folder_path, filename), 'r') as txt_file:
            data = [txt_file.read()]  

            if add_empty_row:
                csv_writer.writerow([''])  
                add_empty_row = False

            csv_writer.writerow(data)

csv_file.close()

# %%
df=pd.read_csv('/content/output2.csv')
df
# Out:
#                                              Unnamed: 0
# 0     أعلنت شركة سوق دبي المالي عن نتائجها المالية ل...
# 1     أبوظبي: مهند داغر شهدت أسواق الأسهم المحلية خل...
# 2     أغلقت الأسهم المحلية قبيل إعلان الولايات المتح...
# 3     أعلن سوق دبي المالي أن قيمة مشتريات الأجانب من...
# 4     أعطت أسواق المال في الدولة خلال الأسبوع الماضي...
# ...                                                 ...
# 6495  بلغت قيمة مشتريات الأجانب، غير العرب، من الأسه...
# 6496  أبوظبي - "الخليج":ارتفع المؤشر العام لسوق أبوظ...
# 6497  قالت مصادر في شركة الدار العقارية إن شركة مباد...
# 6498  واصلت أسواق المنطقة صعودها في جلسة مستهل الأسب...
# 6499  أبوظبي:مهند داغر قادت أسهم العقار، سوق دبي الم...
#
# [6500 rows x 1 columns]

# %%
import os
import csv

folder_path = '/content/Medical'

csv_file = open('output3.csv', 'w', newline='')
csv_writer = csv.writer(csv_file)

add_empty_row = True

for filename in os.listdir(folder_path):
    if filename.endswith('.txt'):
        with open(os.path.join(folder_path, filename), 'r') as txt_file:
            data = [txt_file.read()]  
            if add_empty_row:
                csv_writer.writerow([''])  
                add_empty_row = False

            csv_writer.writerow(data)

csv_file.close()

# %%
dff=pd.read_csv('/content/output3.csv')
dff
# Out:
#                                              Unnamed: 0
# 0     الشارقة: ميرفت الخطيب كشفت جمعية أصدقاء السكري...
# 1     دبي: «الخليج» استقبل خلف أحمد الحبتور، مؤسس ور...
# 2     دبي : «الخليج» تتجه هيئة الصحة بدبي لإجراء توس...
# 3     دبي -"الخليج":تحت رعاية سمو الشيخ حمدان بن راش...
# 4     أبوظبي: «الخليج» أجرى أطباء مستشفى «كليفلاند ك...
# ...                                                 ...
# 6495  دبي: «الخليج» أعلنت «ماجد الفطيم» أمس، عن مباد...
# 6496  يلقي العالم الياباني من أصل عربي، د . فادي الن...
# 6497  أبوظبي- مروان القرعان:كشف الدكتور حمد الغافري ...
# 6498  دبي «الخليج»: أعلنت مؤسسة «بيسكت» في دبي عن مش...
# 6499  أبوظبي - "الخليج":عقدت مجموعة دعم مرضى اللوكيم...
#
# [6500 rows x 1 columns]

# %%
df = df.rename(columns={'Unnamed: 0': 'text'})

# %%
df['label'] = 0

# %%
df
# Out:
#                                                    text  label
# 0     أعلنت شركة سوق دبي المالي عن نتائجها المالية ل...      0
# 1     أبوظبي: مهند داغر شهدت أسواق الأسهم المحلية خل...      0
# 2     أغلقت الأسهم المحلية قبيل إعلان الولايات المتح...      0
# 3     أعلن سوق دبي المالي أن قيمة مشتريات الأجانب من...      0
# 4     أعطت أسواق المال في الدولة خلال الأسبوع الماضي...      0
# ...                                                 ...    ...
# 6495  بلغت قيمة مشتريات الأجانب، غير العرب، من الأسه...      0
# 6496  أبوظبي - "الخليج":ارتفع المؤشر العام لسوق أبوظ...      0
# 6497  قالت مصادر في شركة الدار العقارية إن شركة مباد...      0
# 6498  واصلت أسواق المنطقة صعودها في جلسة مستهل الأسب...      0
# 6499  أبوظبي:مهند داغر قادت أسهم العقار، سوق دبي الم...      0
#
# [6500 rows x 2 columns]

# %%
dff['label'] = 1
dff = dff.rename(columns={'Unnamed: 0': 'text'})

# %%
merged_df = pd.concat([df, dff], axis=0, ignore_index=True)

# %%
merged_df
# Out:
#                                                     text  label
# 0      أعلنت شركة سوق دبي المالي عن نتائجها المالية ل...      0
# 1      أبوظبي: مهند داغر شهدت أسواق الأسهم المحلية خل...      0
# 2      أغلقت الأسهم المحلية قبيل إعلان الولايات المتح...      0
# 3      أعلن سوق دبي المالي أن قيمة مشتريات الأجانب من...      0
# 4      أعطت أسواق المال في الدولة خلال الأسبوع الماضي...      0
# ...                                                  ...    ...
# 12995  دبي: «الخليج» أعلنت «ماجد الفطيم» أمس، عن مباد...      1
# 12996  يلقي العالم الياباني من أصل عربي، د . فادي الن...      1
# 12997  أبوظبي- مروان القرعان:كشف الدكتور حمد الغافري ...      1
# 12998  دبي «الخليج»: أعلنت مؤسسة «بيسكت» في دبي عن مش...      1
# 12999  أبوظبي - "الخليج":عقدت مجموعة دعم مرضى اللوكيم...      1
#
# [13000 rows x 2 columns]

# %%
import os
import csv

folder_path = '/content/Culture'

csv_file = open('output4.csv', 'w', newline='')
csv_writer = csv.writer(csv_file)

add_empty_row = True

for filename in os.listdir(folder_path):
    if filename.endswith('.txt'):
        with open(os.path.join(folder_path, filename), 'r') as txt_file:
            data = [txt_file.read()] 

            if add_empty_row:
                csv_writer.writerow([''])  
                add_empty_row = False

            csv_writer.writerow(data)

csv_file.close()
dfff=pd.read_csv('/content/output4.csv')
dfff = dfff.rename(columns={'Unnamed: 0': 'text'})
dfff['label'] = 2
merged_dff = pd.concat([merged_df, dfff], axis=0, ignore_index=True)

# %%
merged_dff
# Out:
#                                                     text  label
# 0      أعلنت شركة سوق دبي المالي عن نتائجها المالية ل...      0
# 1      أبوظبي: مهند داغر شهدت أسواق الأسهم المحلية خل...      0
# 2      أغلقت الأسهم المحلية قبيل إعلان الولايات المتح...      0
# 3      أعلن سوق دبي المالي أن قيمة مشتريات الأجانب من...      0
# 4      أعطت أسواق المال في الدولة خلال الأسبوع الماضي...      0
# ...                                                  ...    ...
# 19495  ينظم بيت الشعر أمسية يشترك فيها كل من وسام شيا...      2
# 19496  انطلقت مساء الخميس الماضي فعاليات الموسم الثال...      2
# 19497  كتب الشاعر الراحل أحمد راشد ثاني في مطلع شبابه...      2
# 19498  القاهرة «الخليج»: أصدرت دار العين للنشر والتوز...      2
# 19499  يفتتح في السابعة من مساء اليوم معرض للفنان خلي...      2
#
# [19500 rows x 2 columns]

# %%
import os
import csv

folder_path = '/content/Religion'

csv_file = open('output6.csv', 'w', newline='')
csv_writer = csv.writer(csv_file)

add_empty_row = True

for filename in os.listdir(folder_path):
    if filename.endswith('.txt'):
        with open(os.path.join(folder_path, filename), 'r') as txt_file:
            data = [txt_file.read()] 
            if add_empty_row:
                csv_writer.writerow(['']) 
                add_empty_row = False

            csv_writer.writerow(data)

csv_file.close()
ddffff=pd.read_csv('/content/output6.csv')
ddffff = ddffff.rename(columns={'Unnamed: 0': 'text'})
ddffff['label'] = 4
merged_ddfff = pd.concat([merged_dfff, ddffff], axis=0, ignore_index=True)

# %%
import os
import csv

folder_path = '/content/Tech'

csv_file = open('output7.csv', 'w', newline='')
csv_writer = csv.writer(csv_file)

add_empty_row = True

for filename in os.listdir(folder_path):
    if filename.endswith('.txt'):
        with open(os.path.join(folder_path, filename), 'r') as txt_file:
            data = [txt_file.read()]  

            if add_empty_row:
                csv_writer.writerow([''])  
                add_empty_row = False

            csv_writer.writerow(data)

csv_file.close()
dddffff=pd.read_csv('/content/output7.csv')
dddffff = dddffff.rename(columns={'Unnamed: 0': 'text'})
dddffff['label'] = 5
merged_dddfff = pd.concat([merged_ddfff, dddffff], axis=0, ignore_index=True)

# %%
import os
import csv

folder_path = '/content/Sports'

csv_file = open('output8.csv', 'w', newline='')
csv_writer = csv.writer(csv_file)

add_empty_row = True

for filename in os.listdir(folder_path):
    if filename.endswith('.txt'):
        with open(os.path.join(folder_path, filename), 'r') as txt_file:
            data = [txt_file.read()]  

            if add_empty_row:
                csv_writer.writerow([''])  
                add_empty_row = False

            csv_writer.writerow(data)

csv_file.close()
ddddffff=pd.read_csv('/content/output8.csv')
ddddffff = ddddffff.rename(columns={'Unnamed: 0': 'text'})
ddddffff['label'] = 6
merged_ddddfff = pd.concat([merged_dddfff, ddddffff], axis=0, ignore_index=True)

# %%
merged_ddddfff
# Out:
#                                                     text  label
# 0      أعلنت شركة سوق دبي المالي عن نتائجها المالية ل...      0
# 1      أبوظبي: مهند داغر شهدت أسواق الأسهم المحلية خل...      0
# 2      أغلقت الأسهم المحلية قبيل إعلان الولايات المتح...      0
# 3      أعلن سوق دبي المالي أن قيمة مشتريات الأجانب من...      0
# 4      أعطت أسواق المال في الدولة خلال الأسبوع الماضي...      0
# ...                                                  ...    ...
# 45495  حجز أرسنال بطاقته إلى الدور ربع النهائي لمسابق...      6
# 45496  أقال اتحاد مونتينيغرو لكرة القدم مدرب المنتخب ...      6
# 45497  تخوض غانا فرصتها الأخيرة عندما تلاقي بوركينا ف...      6
# 45498  تعاقد نادي برشلونة، بطل الدوري الإسباني أمس مع...      6
# 45499  كانت جماهير القمة بين البرتغال والمكسيك في كأس...      6
#
# [45500 rows x 2 columns]

# %%
data=pd.read_csv("/content/arabic_dataset_classifiction.csv/arabic_dataset_classifiction.csv")

# %%
# !unzip '/content/drive/My Drive/archive (17).zip'
# Out:
# Archive:  /content/drive/My Drive/archive (17).zip
#   inflating: arabic_dataset_classifiction.csv/arabic_dataset_classifiction.csv

# %%
data0=data[data['targe']==0]

# %%
data2=data[data['targe']==2]

# %%
data0 = data0.rename(columns={'targe': 'label'})
data2 = data2.rename(columns={'targe': 'label'})

# %%
data0 = data0.iloc[:6500]
data2 = data2.iloc[:6500]

# %%
data0.loc[:6499, 'label'] = 7

# %%
data0
# Out:
#                                                    text  label
# 0     بين أستوديوهات ورزازات وصحراء مرزوكة وآثار ولي...      7
# 1     قررت النجمة الأمريكية أوبرا وينفري ألا يقتصر ع...      7
# 2     أخبارنا المغربية الوزاني تصوير الشملالي ألهب ا...      7
# 3     اخبارنا المغربية قال ابراهيم الراشدي محامي سعد...      7
# 4     تزال صناعة الجلود في المغرب تتبع الطريقة التقل...      7
# ...                                                 ...    ...
# 6495  بلغ عدد الكتب الرقمية التي تتيح المكتبة الوطني...      7
# 6496  صدر لعبد اللطيف كندة كتاب بعنوان مذكرات مراقب ...      7
# 6497  بالتزامن مع طرحه في بوليود وعرضه في كافة دول ا...      7
# 6498  أخلف المغني الجزائري رضا الطالياني موعده مع جم...      7
# 6499  بعد النجاح الذي حققته أغنية دگدگة يستعد المغني...      7
#
# [6500 rows x 2 columns]

# %%
data2 = data2.drop(columns=['label'])

# %%
data2['label'] = 8

# %%
data2
# Out:
#                                                     text  label
# 30466  وقعت شركة أليانس هوسبيتاليتي ”، فرع الاستثمار ...      8
# 30467  كشفت مجموعة فورد سيارتها الجديدة بي ماكس في ال...      8
# 30468  أفاد مكتب الصرف تراجع قيمة صادرات الفوسفاط ومش...      8
# 30469  حازت أخيرا مجموعة بي إم ترمينال »، التي تدير ا...      8
# 30470  طرحت الخطوط الملكية المغربية أخيرا مجموعة من ا...      8
# ...                                                  ...    ...
# 36961  أخبارنا المغربية من المنتظر ان ينظم موزعو المن...      8
# 36962  انخفض معدل تسويق العقار بالمغرب بشكل كبير في ا...      8
# 36963  أخبارنا المغربية بلغت حقينات السدود الرئيسية ل...      8
# 36964  أخبارنا المغربية بلغ صافي الاحتياطيات الدولية ...      8
# 36965  أخبارنا المغربية أفادت مديرية الخزينة والمالية...      8
#
# [6500 rows x 2 columns]

# %%
data2.label.unique()
# Out:
# array([8])

# %%
FinalDF = pd.concat([data0, data2], axis=0, ignore_index=True)

# %%
FinalDF
# Out:
#                                                     text  label
# 0      بين أستوديوهات ورزازات وصحراء مرزوكة وآثار ولي...      7
# 1      قررت النجمة الأمريكية أوبرا وينفري ألا يقتصر ع...      7
# 2      أخبارنا المغربية الوزاني تصوير الشملالي ألهب ا...      7
# 3      اخبارنا المغربية قال ابراهيم الراشدي محامي سعد...      7
# 4      تزال صناعة الجلود في المغرب تتبع الطريقة التقل...      7
# ...                                                  ...    ...
# 12995  أخبارنا المغربية من المنتظر ان ينظم موزعو المن...      8
# 12996  انخفض معدل تسويق العقار بالمغرب بشكل كبير في ا...      8
# 12997  أخبارنا المغربية بلغت حقينات السدود الرئيسية ل...      8
# 12998  أخبارنا المغربية بلغ صافي الاحتياطيات الدولية ...      8
# 12999  أخبارنا المغربية أفادت مديرية الخزينة والمالية...      8
#
# [13000 rows x 2 columns]

# %%
FinalOfFinal= pd.concat([merged_ddddfff, FinalDF], axis=0, ignore_index=True)

# %%
FinalOfFinal
# Out:
#                                                     text  label
# 0      أعلنت شركة سوق دبي المالي عن نتائجها المالية ل...      0
# 1      أبوظبي: مهند داغر شهدت أسواق الأسهم المحلية خل...      0
# 2      أغلقت الأسهم المحلية قبيل إعلان الولايات المتح...      0
# 3      أعلن سوق دبي المالي أن قيمة مشتريات الأجانب من...      0
# 4      أعطت أسواق المال في الدولة خلال الأسبوع الماضي...      0
# ...                                                  ...    ...
# 58495  أخبارنا المغربية من المنتظر ان ينظم موزعو المن...      8
# 58496  انخفض معدل تسويق العقار بالمغرب بشكل كبير في ا...      8
# 58497  أخبارنا المغربية بلغت حقينات السدود الرئيسية ل...      8
# 58498  أخبارنا المغربية بلغ صافي الاحتياطيات الدولية ...      8
# 58499  أخبارنا المغربية أفادت مديرية الخزينة والمالية...      8
#
# [58500 rows x 2 columns]

# %%
FinalOfFinal.to_csv("Classes.csv")

# %%
output_path = '/content/drive/My Drive/Classes.csv'

# %%
FinalOfFinal.to_csv(output_path, index=False)

# %%
drive=pd.read_csv('/content/drive/MyDrive/Classes.csv')

# %%
drive
# Out:
#                                                     text  label
# 0      أعلنت شركة سوق دبي المالي عن نتائجها المالية ل...      0
# 1      أبوظبي: مهند داغر شهدت أسواق الأسهم المحلية خل...      0
# 2      أغلقت الأسهم المحلية قبيل إعلان الولايات المتح...      0
# 3      أعلن سوق دبي المالي أن قيمة مشتريات الأجانب من...      0
# 4      أعطت أسواق المال في الدولة خلال الأسبوع الماضي...      0
# ...                                                  ...    ...
# 58495  أخبارنا المغربية من المنتظر ان ينظم موزعو المن...      8
# 58496  انخفض معدل تسويق العقار بالمغرب بشكل كبير في ا...      8
# 58497  أخبارنا المغربية بلغت حقينات السدود الرئيسية ل...      8
# 58498  أخبارنا المغربية بلغ صافي الاحتياطيات الدولية ...      8
# 58499  أخبارنا المغربية أفادت مديرية الخزينة والمالية...      8
#
# [58500 rows x 2 columns]
